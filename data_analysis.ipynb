# %%
import os

# Change working directory to the parent directory
os.chdir("/Users/megan/Thesis/")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/megan/Thesis

# %%
import pandas as pd

# Load the data again after reset
file1_path = 'output/baseline_sarimax/final_metrics_summary.csv'
file2_path = 'output/sarimax_with_google_trends/final_metrics_summary.csv'

# Read both CSVs
final_metrics_model1 = pd.read_csv(file1_path)
final_metrics_model2 = pd.read_csv(file2_path)

# Extract MAPE values and compare them
mape_comparison = final_metrics_model1['MAPE'] < final_metrics_model2['MAPE']

# Count how many items perform better in model 1 and model 2
model1_better_count = mape_comparison.sum()
model2_better_count = len(mape_comparison) - model1_better_count

model1_better_count, model2_better_count
# Out:
# (np.int64(315), np.int64(485))

# %%
# Calculate MAPE for Model 1 and Model 2
model_1_mape = final_metrics_model1['MAPE']
model_2_mape = final_metrics_model2['MAPE']

# Calculate the absolute difference in MAPE for each item
mape_difference = model_1_mape - model_2_mape

# Calculate the average MAPE difference
average_mape_difference = mape_difference.mean()

# Calculate the percentage decrease in MAPE for Model 2
percentage_decrease = (average_mape_difference / model_1_mape.mean()) * 100

average_mape_difference, percentage_decrease
# Out:
# (np.float64(-21.339726731373457), np.float64(-69.03004626033781))

# %%
model_1_mape.mean()
# Out:
# np.float64(30.91367873475481)

# %%
import pandas as pd

# Load preprocessed
grouped_data = pd.read_csv('data/top_800_product_groups.csv')
grouped_data['date'] = pd.to_datetime(grouped_data['date'], errors='coerce')
grouped_data.columns
data = grouped_data

# %%
import pandas as pd

# Load Metrics (Performance Results)
metrics_path = "output/baseline_sarimax/final_metrics_summary.csv"
metrics_df = pd.read_csv(metrics_path)

# Load Transaction Data (To Compute % Days with Transactions)
data_path = "data/top_800_product_groups.csv"
grouped_data = pd.read_csv(data_path)

# ✅ Ensure Column Names Match (Rename for Consistency)
metrics_df.rename(columns={"Unnamed: 0": "product_group"}, inplace=True)
grouped_data.rename(columns={"Product Group": "product_group"}, inplace=True)

# ✅ Debug: Print column names if needed
print("Metrics Columns:", metrics_df.columns)
print("Grouped Data Columns:", grouped_data.columns)

# Ensure `date` is in datetime format
grouped_data['date'] = pd.to_datetime(grouped_data['date'], errors='coerce')

# Count days with transactions per product group
transaction_days = grouped_data.groupby('product_group')['transaction_count'].apply(lambda x: (x > 0).sum())

# Compute total days per product group
total_days = grouped_data.groupby('product_group')['date'].count()

# Calculate coverage percentage (non-zero transaction days / total days)
coverage_df = (transaction_days / total_days).reset_index()
coverage_df.columns = ['product_group', 'coverage']

# ✅ Check if `product_group` exists in both before merging
if 'product_group' in metrics_df.columns and 'product_group' in coverage_df.columns:
    merged_df = metrics_df.merge(coverage_df, on='product_group', how='left')
else:
    print("⚠️ 'product_group' column missing in one of the DataFrames!")
    print("Metrics DF columns:", metrics_df.columns)
    print("Coverage DF columns:", coverage_df.columns)
    exit()  # Stop execution if there's a problem

# Remove low-coverage product groups (<80% transactions)
filtered_df = merged_df[merged_df['coverage'] >= 0.8].copy()

# Drop coverage column after filtering
filtered_df.drop(columns=['coverage'], inplace=True)

# Save cleaned metrics
filtered_df.to_csv("output/baseline_sarimax/filtered_metrics_summary.csv", index=False)

# ✅ Recalculate Average Metrics After Removing Outliers
avg_metrics = {
    'MAE': filtered_df['MAE'].mean(),
    'RMSE': filtered_df['RMSE'].mean(),
    'MAPE': filtered_df['MAPE'].mean(),
    'R2': filtered_df['R2'].mean()
}

# Save new averages
pd.DataFrame([avg_metrics]).to_csv("output/baseline_sarimax/filtered_avg_metrics.csv", index=False)

print("\n✅ Process complete: Outliers removed based on <80% transaction coverage.")
print("\n📊 New Average Metrics:")
print(pd.DataFrame([avg_metrics]))
# Out:
# Metrics Columns: Index(['product_group', 'MAE', 'RMSE', 'MAPE', 'R2'], dtype='object')
# Grouped Data Columns: Index(['date', 'product_group', 'transaction_count', 'avg_price',
#        'unique_customers', 'std_price', 'unique_articles_sold', 'median_age',
#        'club_member_ratio', 'fashion_news_subscribers',
#        'first_purchase_days_ago', 'recent_purchase_days_ago',
#        'sales_channel_2', 'most_common_age_bin_20-29',
#        'most_common_age_bin_30-39', 'most_common_age_bin_40-49',
#        'most_common_age_bin_50-59', 'most_common_age_bin_60+'],
#       dtype='object')
#
# ✅ Process complete: Outliers removed based on <80% transaction coverage.
#
# 📊 New Average Metrics:
#         MAE       RMSE       MAPE          R2
# 0  4.770862  10.983168  30.913679 -431.830377

# %%
import pandas as pd

# Load Metrics (Performance Results)
metrics_path = "output/baseline_sarimax_14_days/final_metrics_summary.csv"
metrics_df = pd.read_csv(metrics_path)

# Load Transaction Data (To Compute % Days with Transactions)
data_path = "data/top_800_product_groups.csv"
grouped_data = pd.read_csv(data_path)

# ✅ Ensure Column Names Match (Rename for Consistency)
metrics_df.rename(columns={"Unnamed: 0": "product_group"}, inplace=True)
grouped_data.rename(columns={"Product Group": "product_group"}, inplace=True)

# ✅ Debug: Print column names if needed
print("Metrics Columns:", metrics_df.columns)
print("Grouped Data Columns:", grouped_data.columns)

# Ensure `date` is in datetime format
grouped_data['date'] = pd.to_datetime(grouped_data['date'], errors='coerce')

# Count days with transactions per product group
transaction_days = grouped_data.groupby('product_group')['transaction_count'].apply(lambda x: (x > 0).sum())

# Compute total days per product group
total_days = grouped_data.groupby('product_group')['date'].count()

# Calculate coverage percentage (non-zero transaction days / total days)
coverage_df = (transaction_days / total_days).reset_index()
coverage_df.columns = ['product_group', 'coverage']

# ✅ Check if `product_group` exists in both before merging
if 'product_group' in metrics_df.columns and 'product_group' in coverage_df.columns:
    merged_df = metrics_df.merge(coverage_df, on='product_group', how='left')
else:
    print("⚠️ 'product_group' column missing in one of the DataFrames!")
    print("Metrics DF columns:", metrics_df.columns)
    print("Coverage DF columns:", coverage_df.columns)
    exit()  # Stop execution if there's a problem

# Remove low-coverage product groups (<80% transactions)
filtered_df = merged_df[merged_df['coverage'] >= 0.8].copy()

# Drop coverage column after filtering
filtered_df.drop(columns=['coverage'], inplace=True)

# Save cleaned metrics
filtered_df.to_csv("output/baseline_sarimax/filtered_metrics_summary.csv", index=False)

# ✅ Recalculate Average Metrics After Removing Outliers
avg_metrics = {
    'MAE': filtered_df['MAE'].mean(),
    'RMSE': filtered_df['RMSE'].mean(),
    'MAPE': filtered_df['MAPE'].mean(),
    'R2': filtered_df['R2'].mean()
}

# Save new averages
pd.DataFrame([avg_metrics]).to_csv("output/baseline_sarimax/filtered_avg_metrics.csv", index=False)

print("\n✅ Process complete: Outliers removed based on <80% transaction coverage.")
print("\n📊 New Average Metrics:")
print(pd.DataFrame([avg_metrics]))
# Out:
# Metrics Columns: Index(['product_group', 'MAE', 'RMSE', 'MAPE', 'R2'], dtype='object')
# Grouped Data Columns: Index(['date', 'product_group', 'transaction_count', 'avg_price',
#        'unique_customers', 'std_price', 'unique_articles_sold', 'median_age',
#        'club_member_ratio', 'fashion_news_subscribers',
#        'first_purchase_days_ago', 'recent_purchase_days_ago',
#        'sales_channel_2', 'most_common_age_bin_20-29',
#        'most_common_age_bin_30-39', 'most_common_age_bin_40-49',
#        'most_common_age_bin_50-59', 'most_common_age_bin_60+'],
#       dtype='object')
#
# ✅ Process complete: Outliers removed based on <80% transaction coverage.
#
# 📊 New Average Metrics:
#         MAE      RMSE       MAPE        R2
# 0  2.290747  2.977739  16.346171 -0.852919

# %%
import pandas as pd

# Load Metrics (Performance Results)
metrics_path = "output/baseline_sarimax/final_metrics_summary.csv"
metrics_df = pd.read_csv(metrics_path)

# Define the full 2-year period (inclusive)
full_period_start = pd.to_datetime("2018-09-20")
full_period_end = pd.to_datetime("2020-09-22")
total_days_in_range = (full_period_end - full_period_start).days + 1  # 734 days

# Load Transaction Data (To Compute % Days with Transactions)
data_path = "data/top_800_product_groups.csv"
grouped_data = pd.read_csv(data_path)

# Ensure Column Names Match (Rename for Consistency)
metrics_df.rename(columns={"Unnamed: 0": "product_group"}, inplace=True)
grouped_data.rename(columns={"Product Group": "product_group"}, inplace=True)

# Ensure `date` is in datetime format
grouped_data['date'] = pd.to_datetime(grouped_data['date'], errors='coerce')

# Count the number of days with transactions per product group
transaction_days = grouped_data.groupby('product_group')['transaction_count'].apply(lambda x: (x > 0).sum())

# Use the fixed total days in range for coverage calculation
coverage_df = (transaction_days / total_days_in_range).reset_index()
coverage_df.columns = ['product_group', 'coverage']

# Merge coverage info with metrics
merged_df = metrics_df.merge(coverage_df, on='product_group', how='left')

# Identify Outliers (Based on Low Coverage <80% or High MAPE/R² Issues)
outliers_df = merged_df[(merged_df['coverage'] < 0.8) | (merged_df['MAPE'] > 100) | (merged_df['R2'] < 0)]

# Save the outliers to a CSV file
output_file_path = "output/baseline_sarimax/outliers_summary.csv"
outliers_df.to_csv(output_file_path, index=False)
outliers_df
# Out:
#                                   product_group         MAE         RMSE  \
# 8             Bikini top Beige All over pattern   13.047463    18.170007
# 16       Bikini top Dark Green All over pattern    4.658369     7.455192
# 21      Bikini top Light Beige All over pattern    6.318970    27.223031
# 22       Bikini top Light Blue All over pattern    5.499646     6.888212
# 23                  Bikini top Light Blue Solid   16.706606    20.244897
# ..                                          ...         ...          ...
# 795       Bikini top Other Pink Other structure    7.122505    12.220479
# 796  Swimwear bottom Other Pink Other structure   23.632806    31.617869
# 797     Bikini top Light Purple Other structure  611.879133  4167.335031
# 798                 Dress White Other structure    2.239700     2.722363
# 799              Swimwear bottom Dark Green Dot    8.627599    10.131744
#
#            MAPE             R2  coverage
# 8    119.972401      -0.420493  0.615804
# 16    30.474968       0.886069  0.634877
# 21    72.207053       0.862306  0.771117
# 22   200.716594       0.583783  0.780654
# 23   792.110492      -4.689503  0.606267
# ..          ...            ...       ...
# 795   32.246653       0.619691  0.373297
# 796  135.770396      -3.361680  0.371935
# 797   40.050463 -341072.719578  0.299728
# 798   19.650136       0.926608  0.254768
# 799   53.587480       0.323033  0.235695
#
# [151 rows x 6 columns]

# %%
import pandas as pd

# Load Metrics (Performance Results)
metrics_path = "output/baseline_sarimax_14_days/final_metrics_summary.csv"
metrics_df = pd.read_csv(metrics_path)

# Define the full 2-year period (inclusive)
full_period_start = pd.to_datetime("2018-09-20")
full_period_end = pd.to_datetime("2020-09-22")
total_days_in_range = (full_period_end - full_period_start).days + 1  # 734 days

# Load Transaction Data (To Compute % Days with Transactions)
data_path = "data/top_800_product_groups.csv"
grouped_data = pd.read_csv(data_path)

# Ensure Column Names Match (Rename for Consistency)
metrics_df.rename(columns={"Unnamed: 0": "product_group"}, inplace=True)
grouped_data.rename(columns={"Product Group": "product_group"}, inplace=True)

# Ensure `date` is in datetime format
grouped_data['date'] = pd.to_datetime(grouped_data['date'], errors='coerce')

# Count the number of days with transactions per product group
transaction_days = grouped_data.groupby('product_group')['transaction_count'].apply(lambda x: (x > 0).sum())

# Use the fixed total days in range for coverage calculation
coverage_df = (transaction_days / total_days_in_range).reset_index()
coverage_df.columns = ['product_group', 'coverage']

# Merge coverage info with metrics
merged_df = metrics_df.merge(coverage_df, on='product_group', how='left')

# Identify Outliers (Based on Low Coverage <80% or High MAPE/R² Issues)
outliers_df = merged_df[(merged_df['coverage'] < 0.8) | (merged_df['MAPE'] > 100) | (merged_df['R2'] < 0)]

# Save the outliers to a CSV file
output_file_path = "output/baseline_sarimax_14_days/outliers_summary.csv"
outliers_df.to_csv(output_file_path, index=False)
outliers_df
# Out:
#                                   product_group       MAE      RMSE  \
# 8             Bikini top Beige All over pattern  3.009779  3.974976
# 16       Bikini top Dark Green All over pattern  2.530283  2.894461
# 21      Bikini top Light Beige All over pattern  3.133449  4.014688
# 22       Bikini top Light Blue All over pattern  1.865285  2.635603
# 23                  Bikini top Light Blue Solid  4.357989  4.707166
# ..                                          ...       ...       ...
# 795       Bikini top Other Pink Other structure  2.975118  3.704403
# 796  Swimwear bottom Other Pink Other structure  2.996066  4.322782
# 797     Bikini top Light Purple Other structure  4.768365  6.174249
# 798                 Dress White Other structure  2.235732  2.711287
# 799              Swimwear bottom Dark Green Dot  5.507632  6.242999
#
#           MAPE        R2  coverage
# 8    44.346719  0.417361  0.615804
# 16   14.222212  0.946437  0.634877
# 21   40.969789 -0.289346  0.771117
# 22   16.590180  0.682210  0.780654
# 23   35.675518  0.745122  0.606267
# ..         ...       ...       ...
# 795  10.565924  0.895663  0.373297
# 796   9.250471  0.922707  0.371935
# 797  20.775591  0.645914  0.299728
# 798  15.083347  0.876597  0.254768
# 799  32.348728  0.634636  0.235695
#
# [140 rows x 6 columns]

# %%
import pandas as pd

# Load Metrics (Performance Results)
metrics_path = "output/sarimax_with_google_trends/final_metrics_summary.csv"
metrics_df = pd.read_csv(metrics_path)

# Define the full 2-year period (inclusive)
full_period_start = pd.to_datetime("2018-09-20")
full_period_end = pd.to_datetime("2020-09-22")
total_days_in_range = (full_period_end - full_period_start).days + 1  # 734 days

# Load Transaction Data (To Compute % Days with Transactions)
data_path = "data/top_800_product_groups.csv"
grouped_data = pd.read_csv(data_path)

# Ensure Column Names Match (Rename for Consistency)
metrics_df.rename(columns={"Unnamed: 0": "product_group"}, inplace=True)
grouped_data.rename(columns={"Product Group": "product_group"}, inplace=True)

# Ensure `date` is in datetime format
grouped_data['date'] = pd.to_datetime(grouped_data['date'], errors='coerce')

# Count the number of days with transactions per product group
transaction_days = grouped_data.groupby('product_group')['transaction_count'].apply(lambda x: (x > 0).sum())

# Use the fixed total days in range for coverage calculation
coverage_df = (transaction_days / total_days_in_range).reset_index()
coverage_df.columns = ['product_group', 'coverage']

# Merge coverage info with metrics
merged_df = metrics_df.merge(coverage_df, on='product_group', how='left')

# Identify Outliers (Based on Low Coverage <80% or High MAPE/R² Issues)
outliers_df = merged_df[(merged_df['coverage'] < 0.8) | (merged_df['MAPE'] > 100) | (merged_df['R2'] < 0)]

# Save the outliers to a CSV file
output_file_path = "output/sarimax_with_google_trends/outliers_summary.csv"
outliers_df.to_csv(output_file_path, index=False)
outliers_df
# Out:
#                                   product_group          MAE         RMSE  \
# 8             Bikini top Beige All over pattern     2.174139     3.083534
# 16       Bikini top Dark Green All over pattern     9.244047    17.197817
# 21      Bikini top Light Beige All over pattern     5.639414    24.709763
# 22       Bikini top Light Blue All over pattern     5.291732     6.374338
# 23                  Bikini top Light Blue Solid    18.923580    22.443696
# ..                                          ...          ...          ...
# 795       Bikini top Other Pink Other structure     6.314757     9.308901
# 796  Swimwear bottom Other Pink Other structure  2371.502677  3185.511714
# 797     Bikini top Light Purple Other structure     8.913606    35.354849
# 798                 Dress White Other structure     4.008262     4.492692
# 799              Swimwear bottom Dark Green Dot    58.935188   144.264663
#
#              MAPE            R2  coverage
# 8       46.882761      0.855297  0.615804
# 16      44.302012      0.666400  0.634877
# 21      68.094480      0.860250  0.771117
# 22     191.182234      0.654124  0.780654
# 23     918.723791     -6.156361  0.606267
# ..            ...           ...       ...
# 795     30.536757      0.811067  0.373297
# 796  13399.786448 -56220.145510  0.371935
# 797     42.319914    -17.431904  0.299728
# 798     25.174260      0.855021  0.254768
# 799     44.024540  -8664.477608  0.235695
#
# [152 rows x 6 columns]

# %%
import pandas as pd

# Load Metrics (Performance Results)
metrics_path = "output/sarimax_with_google_trends_14_days/final_metrics_summary.csv"
metrics_df = pd.read_csv(metrics_path)

# Define the full 2-year period (inclusive)
full_period_start = pd.to_datetime("2018-09-20")
full_period_end = pd.to_datetime("2020-09-22")
total_days_in_range = (full_period_end - full_period_start).days + 1  # 734 days

# Load Transaction Data (To Compute % Days with Transactions)
data_path = "data/top_800_product_groups.csv"
grouped_data = pd.read_csv(data_path)

# Ensure Column Names Match (Rename for Consistency)
metrics_df.rename(columns={"Unnamed: 0": "product_group"}, inplace=True)
grouped_data.rename(columns={"Product Group": "product_group"}, inplace=True)

# Ensure `date` is in datetime format
grouped_data['date'] = pd.to_datetime(grouped_data['date'], errors='coerce')

# Count the number of days with transactions per product group
transaction_days = grouped_data.groupby('product_group')['transaction_count'].apply(lambda x: (x > 0).sum())

# Use the fixed total days in range for coverage calculation
coverage_df = (transaction_days / total_days_in_range).reset_index()
coverage_df.columns = ['product_group', 'coverage']

# Merge coverage info with metrics
merged_df = metrics_df.merge(coverage_df, on='product_group', how='left')

# Identify Outliers (Based on Low Coverage <80% or High MAPE/R² Issues)
outliers_df = merged_df[(merged_df['coverage'] < 0.8) | (merged_df['MAPE'] > 100) | (merged_df['R2'] < 0)]

# Save the outliers to a CSV file
output_file_path = "output/sarimax_with_google_trends_14_days/outliers_summary.csv"
outliers_df.to_csv(output_file_path, index=False)
outliers_df
# Out:
#                                   product_group        MAE        RMSE  \
# 8             Bikini top Beige All over pattern   2.182917    2.844289
# 16       Bikini top Dark Green All over pattern   2.911611    3.263871
# 21      Bikini top Light Beige All over pattern   3.067308    3.806347
# 22       Bikini top Light Blue All over pattern   2.129347    2.842672
# 23                  Bikini top Light Blue Solid   4.644265    5.041362
# ..                                          ...        ...         ...
# 795       Bikini top Other Pink Other structure   2.984598    3.673566
# 796  Swimwear bottom Other Pink Other structure   3.124763    4.399976
# 797     Bikini top Light Purple Other structure   4.220636    5.525455
# 798                 Dress White Other structure   3.124570    3.504533
# 799              Swimwear bottom Dark Green Dot  35.518723  118.547822
#
#           MAPE           R2  coverage
# 8    19.202573     0.810273  0.615804
# 16   17.966805     0.928621  0.634877
# 21   28.870400     0.318340  0.771117
# 22   18.215975     0.659966  0.780654
# 23   37.758587     0.676686  0.606267
# ..         ...          ...       ...
# 795   9.215783     0.912122  0.373297
# 796   9.408233     0.930636  0.371935
# 797  16.365569     0.736177  0.299728
# 798  18.778477     0.821645  0.254768
# 799  30.839016 -4894.443411  0.235695
#
# [139 rows x 6 columns]

# %%
import pandas as pd

# Load Metrics (Performance Results)
metrics_path = "output/sarimax_with_google_trends/final_metrics_summary.csv"
metrics_df = pd.read_csv(metrics_path)

# Load Transaction Data (To Compute % Days with Transactions)
data_path = "data/top_800_product_groups.csv"
grouped_data = pd.read_csv(data_path)

# ✅ Ensure Column Names Match (Rename for Consistency)
metrics_df.rename(columns={"Unnamed: 0": "product_group"}, inplace=True)
grouped_data.rename(columns={"Product Group": "product_group"}, inplace=True)

# ✅ Debug: Print column names if needed
print("Metrics Columns:", metrics_df.columns)
print("Grouped Data Columns:", grouped_data.columns)

# Ensure `date` is in datetime format
grouped_data['date'] = pd.to_datetime(grouped_data['date'], errors='coerce')

# Count days with transactions per product group
transaction_days = grouped_data.groupby('product_group')['transaction_count'].apply(lambda x: (x > 0).sum())

# Compute total days per product group
total_days = grouped_data.groupby('product_group')['date'].count()

# Calculate coverage percentage (non-zero transaction days / total days)
coverage_df = (transaction_days / total_days).reset_index()
coverage_df.columns = ['product_group', 'coverage']

# ✅ Check if `product_group` exists in both before merging
if 'product_group' in metrics_df.columns and 'product_group' in coverage_df.columns:
    merged_df = metrics_df.merge(coverage_df, on='product_group', how='left')
else:
    print("⚠️ 'product_group' column missing in one of the DataFrames!")
    print("Metrics DF columns:", metrics_df.columns)
    print("Coverage DF columns:", coverage_df.columns)
    exit()  # Stop execution if there's a problem

# Remove low-coverage product groups (<80% transactions)
filtered_df = merged_df[merged_df['coverage'] >= 0.8].copy()

# Drop coverage column after filtering
filtered_df.drop(columns=['coverage'], inplace=True)

# Save cleaned metrics
filtered_df.to_csv("output/baseline_sarimax/filtered_metrics_summary.csv", index=False)

# ✅ Recalculate Average Metrics After Removing Outliers
avg_metrics = {
    'MAE': filtered_df['MAE'].mean(),
    'RMSE': filtered_df['RMSE'].mean(),
    'MAPE': filtered_df['MAPE'].mean(),
    'R2': filtered_df['R2'].mean()
}

# Save new averages
pd.DataFrame([avg_metrics]).to_csv("output/baseline_sarimax/filtered_avg_metrics.csv", index=False)

print("\n✅ Process complete: Outliers removed based on <80% transaction coverage.")
print("\n📊 New Average Metrics:")
print(pd.DataFrame([avg_metrics]))
# Out:
# Metrics Columns: Index(['product_group', 'MAE', 'RMSE', 'MAPE', 'R2'], dtype='object')
# Grouped Data Columns: Index(['date', 'product_group', 'transaction_count', 'avg_price',
#        'unique_customers', 'std_price', 'unique_articles_sold', 'median_age',
#        'club_member_ratio', 'fashion_news_subscribers',
#        'first_purchase_days_ago', 'recent_purchase_days_ago',
#        'sales_channel_2', 'most_common_age_bin_20-29',
#        'most_common_age_bin_30-39', 'most_common_age_bin_40-49',
#        'most_common_age_bin_50-59', 'most_common_age_bin_60+'],
#       dtype='object')
#
# ✅ Process complete: Outliers removed based on <80% transaction coverage.
#
# 📊 New Average Metrics:
#         MAE       RMSE       MAPE         R2
# 0  8.694712  13.045464  52.253405 -117.65704

# %%
subset_df = data[data['product_group'] == 'Pyjama bottom Black Solid'].copy()

# Print or display the subset
print("Rows for 'Pyjama bottom Black Solid':")
print(subset_df)

print("Max transaction_count:", subset_df['transaction_count'].max())
print("Min transaction_count:", subset_df['transaction_count'].min())
print("Number of rows:", len(subset_df))
# Out:
# Rows for 'Pyjama bottom Black Solid':
#              date              product_group  transaction_count  avg_price  \
# 286    2018-09-20  Pyjama bottom Black Solid                 18   0.016603
# 991    2018-09-21  Pyjama bottom Black Solid                 19   0.016843
# 1668   2018-09-22  Pyjama bottom Black Solid                  8   0.016932
# 2324   2018-09-23  Pyjama bottom Black Solid                 29   0.016932
# 3023   2018-09-24  Pyjama bottom Black Solid                 44   0.016913
# ...           ...                        ...                ...        ...
# 531727 2020-09-18  Pyjama bottom Black Solid                 20   0.016568
# 532423 2020-09-19  Pyjama bottom Black Solid                 21   0.016852
# 533117 2020-09-20  Pyjama bottom Black Solid                 18   0.016374
# 533814 2020-09-21  Pyjama bottom Black Solid                 19   0.016637
# 534503 2020-09-22  Pyjama bottom Black Solid                 14   0.016827
#
#         unique_customers  std_price  unique_articles_sold  median_age  \
# 286                   16   0.001054                     1        31.5
# 991                   16   0.000389                     1        32.0
# 1668                   7   0.000000                     1        41.5
# 2324                  24   0.000000                     1        30.0
# 3023                  36   0.000128                     1        28.0
# ...                  ...        ...                   ...         ...
# 531727                17   0.001177                     2        33.5
# 532423                17   0.000189                     1        31.0
# 533117                16   0.001681                     1        30.0
# 533814                19   0.000591                     1        34.0
# 534503                14   0.000295                     1        33.5
#
#         club_member_ratio  fashion_news_subscribers  first_purchase_days_ago  \
# 286                   0.0                         6                     2316
# 991                   0.0                         6                     2316
# 1668                  0.0                         6                     2316
# 2324                  0.0                        13                     2316
# 3023                  0.0                        15                     2316
# ...                   ...                       ...                      ...
# 531727                0.0                        11                     1815
# 532423                0.0                        12                     2316
# 533117                0.0                         3                     2316
# 533814                0.0                         7                     2316
# 534503                0.0                         5                     2316
#
#         recent_purchase_days_ago  sales_channel_2  most_common_age_bin_20-29  \
# 286                         1583                1                          1
# 991                         1587                1                          1
# 1668                        1586                1                          1
# 2324                        1584                1                          1
# 3023                        1583                1                          1
# ...                          ...              ...                        ...
# 531727                      1583                0                          1
# 532423                      1583                1                          0
# 533117                      1585                1                          1
# 533814                      1584                1                          0
# 534503                      1583                1                          0
#
#         most_common_age_bin_30-39  most_common_age_bin_40-49  \
# 286                             0                          0
# 991                             0                          0
# 1668                            0                          0
# 2324                            0                          0
# 3023                            0                          0
# ...                           ...                        ...
# 531727                          0                          0
# 532423                          1                          0
# 533117                          0                          0
# 533814                          0                          0
# 534503                          1                          0
#
#         most_common_age_bin_50-59  most_common_age_bin_60+
# 286                             0                        0
# 991                             0                        0
# 1668                            0                        0
# 2324                            0                        0
# 3023                            0                        0
# ...                           ...                      ...
# 531727                          0                        0
# 532423                          0                        0
# 533117                          0                        0
# 533814                          1                        0
# 534503                          0                        0
#
# [731 rows x 18 columns]
# Max transaction_count: 153
# Min transaction_count: 1
# Number of rows: 731

# %%
import pandas as pd

# Filter for the product group of interest
product_group = "Underwear bottom Dark Red Solid"
df_pg = data[data['product_group'] == product_group].copy()

# Ensure 'date' is datetime and sort
df_pg['date'] = pd.to_datetime(df_pg['date'])
df_pg = df_pg.set_index('date').asfreq('D').fillna(0)  # Fill missing days with 0

# Summary statistics
summary_stats = df_pg['transaction_count'].describe()

# Count days with zero sales
zero_sales_days = (df_pg['transaction_count'] == 0).sum()
total_days = df_pg.shape[0]
zero_sales_pct = (zero_sales_days / total_days) * 100

print(f"Product Group: {product_group}")
print(f"Total Days: {total_days}")
print(f"Days with Zero Sales: {zero_sales_days} ({zero_sales_pct:.2f}%)")
print(summary_stats)
# Out:
# Product Group: Underwear bottom Dark Red Solid
# Total Days: 734
# Days with Zero Sales: 16 (2.18%)
# count     734.000000
# mean       88.882834
# std       109.761393
# min         0.000000
# 25%        14.000000
# 50%        55.000000
# 75%       136.750000
# max      1444.000000
# Name: transaction_count, dtype: float64

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import TimeSeriesSplit
from tqdm import tqdm
from modules.utils import process_name

output_dir = "output/baseline_sarimax_one_item_dropped_cols"
os.makedirs(output_dir, exist_ok=True)

# We'll still run only on this item of interest
item_of_interest = "Bikini top Blue Stripe"
sanitized_item_name = process_name(item_of_interest)  # Convert to safe filename

df_item = grouped_data[grouped_data['product_group'] == item_of_interest].copy()

# Convert date to datetime index
df_item['date'] = pd.to_datetime(df_item['date'])
df_item = df_item.set_index('date').asfreq('D').fillna(0)

# Define endog
endog = df_item['transaction_count']

# List out exogenous columns, dropping certain columns
drop_cols = ['transaction_count', 'product_group', 'std_price', 'club_member_ratio']
exog_cols = [c for c in df_item.columns if c not in drop_cols]
exog = df_item[exog_cols] if exog_cols else None

# TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=4)
if len(df_item) < (tscv.n_splits + 1):
    print(f"Not enough data points ({len(df_item)}) for 4 splits.")
    exit()

fold_metrics = []
fig, axes = plt.subplots(tscv.n_splits, 2, figsize=(20, 8 * tscv.n_splits))
fig.suptitle(f"{item_of_interest}: Drop 'std_price' & 'club_member_ratio'", fontsize=16, y=0.95)

for fold, (train_index, test_index) in enumerate(tscv.split(df_item)):
    train_endog = endog.iloc[train_index]
    test_endog = endog.iloc[test_index]
    train_exog = exog.iloc[train_index] if exog is not None else None
    test_exog = exog.iloc[test_index] if exog is not None else None

    model = SARIMAX(
        train_endog,
        exog=train_exog,
        order=(1, 1, 1),
        seasonal_order=(1, 1, 1, 7)
    )
    results = model.fit(disp=False, maxiter=500)

    print(f"\n=== Fold {fold+1} - Model Summary (Dropping std_price & club_member_ratio) ===")
    print(results.summary())

    pred = results.get_prediction(
        start=test_endog.index[0],
        end=test_endog.index[-1],
        exog=test_exog
    )
    pred_mean = np.maximum(pred.predicted_mean, 0)

    mae = mean_absolute_error(test_endog, pred_mean)
    rmse = np.sqrt(mean_squared_error(test_endog, pred_mean))
    # Avoid dividing by zero
    mape = np.mean(np.abs((test_endog - pred_mean) / test_endog.replace(0, np.nan))) * 100
    r2 = r2_score(test_endog, pred_mean)

    fold_metrics.append({
        "Fold": fold + 1,
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2
    })

    # Plots
    axes[fold, 0].plot(test_endog.index, test_endog, label="Actual", alpha=0.7)
    axes[fold, 0].plot(test_endog.index, pred_mean, label="Predicted", alpha=0.7, linestyle='--')
    axes[fold, 0].set_title(f"Fold {fold+1}: Predicted vs Actual", fontsize=12)
    axes[fold, 0].legend()

    residuals = test_endog - pred_mean
    axes[fold, 1].plot(test_endog.index, residuals, label="Residuals")
    axes[fold, 1].axhline(0, linestyle="--", alpha=0.7)
    axes[fold, 1].set_title(f"Fold {fold+1}: Residuals", fontsize=12)
    axes[fold, 1].legend()

plt.tight_layout(rect=[0, 0, 1, 0.95])

# Use 'sanitized_item_name' in filenames
plot_path = os.path.join(output_dir, f"{sanitized_item_name}_drop_cols_cv.png")
plt.savefig(plot_path)
plt.close(fig)

metrics_df = pd.DataFrame(fold_metrics)
metrics_df_path = os.path.join(output_dir, f"{sanitized_item_name}_drop_cols_fold_metrics.csv")
metrics_df.to_csv(metrics_df_path, index=False)

avg_metrics = {
    'MAE': metrics_df['MAE'].mean(),
    'RMSE': metrics_df['RMSE'].mean(),
    'MAPE': metrics_df['MAPE'].mean(),
    'R2': metrics_df['R2'].mean()
}
avg_metrics_df = pd.DataFrame([avg_metrics])
avg_metrics_df_path = os.path.join(output_dir, f"{sanitized_item_name}_drop_cols_avg_metrics.csv")
avg_metrics_df.to_csv(avg_metrics_df_path, index=False)

print("\n===== Done! =====")
print(f"Fold metrics saved to: {metrics_df_path}")
print("Average metrics:\n", avg_metrics_df)
print(f"Plots saved to: {plot_path}")
# Out:
# === Fold 1 - Model Summary (Dropping std_price & club_member_ratio) ===
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                 transaction_count   No. Observations:                  121
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood                -341.002
# Date:                           Thu, 06 Feb 2025   AIC                            718.003
# Time:                                   16:46:45   BIC                            767.096
# Sample:                               02-12-2019   HQIC                           737.925
#                                     - 06-12-2019
# Covariance Type:                             opg
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# avg_price                  2359.0453    614.819      3.837      0.000    1154.022    3564.069
# unique_customers              1.3341      0.059     22.568      0.000       1.218       1.450
# unique_articles_sold         -7.2343      3.282     -2.204      0.028     -13.667      -0.801
# median_age                    0.0994      0.229      0.434      0.664      -0.350       0.548
# fashion_news_subscribers      0.1818      0.089      2.033      0.042       0.006       0.357
# first_purchase_days_ago      -0.7481      0.279     -2.677      0.007      -1.296      -0.200
# recent_purchase_days_ago     -0.0090      0.032     -0.283      0.777      -0.071       0.053
# sales_channel_2             9.59e-05   2.67e+05    3.6e-10      1.000   -5.23e+05    5.23e+05
# most_common_age_bin_20-29     3.2685    8.8e+04   3.71e-05      1.000   -1.73e+05    1.73e+05
# most_common_age_bin_30-39    -0.8850    8.8e+04  -1.01e-05      1.000   -1.73e+05    1.73e+05
# most_common_age_bin_40-49          0   3181.582          0      1.000   -6235.786    6235.786
# most_common_age_bin_50-59    -2.3834    8.8e+04  -2.71e-05      1.000   -1.73e+05    1.73e+05
# most_common_age_bin_60+            0   3181.604          0      1.000   -6235.828    6235.828
# ar.L1                        -0.0092      0.134     -0.069      0.945      -0.272       0.253
# ma.L1                        -0.9968      0.687     -1.450      0.147      -2.344       0.350
# ar.S.L7                       0.0568      0.150      0.379      0.705      -0.237       0.351
# ma.S.L7                      -0.9971      5.246     -0.190      0.849     -11.279       9.285
# sigma2                       19.3622    102.131      0.190      0.850    -180.811     219.536
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.51
# Prob(Q):                              0.93   Prob(JB):                         0.77
# Heteroskedasticity (H):               1.03   Skew:                             0.10
# Prob(H) (two-sided):                  0.93   Kurtosis:                         2.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.21e+20. Standard errors may be unstable.
#
# === Fold 2 - Model Summary (Dropping std_price & club_member_ratio) ===
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                 transaction_count   No. Observations:                  238
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood                -618.509
# Date:                           Thu, 06 Feb 2025   AIC                           1273.018
# Time:                                   16:46:47   BIC                           1334.904
# Sample:                               02-12-2019   HQIC                          1297.982
#                                     - 10-07-2019
# Covariance Type:                             opg
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# avg_price                   149.4427    220.943      0.676      0.499    -283.598     582.483
# unique_customers              1.2428      0.032     38.907      0.000       1.180       1.305
# unique_articles_sold         -1.0005      0.586     -1.707      0.088      -2.149       0.148
# median_age                    0.1514      0.110      1.381      0.167      -0.063       0.366
# fashion_news_subscribers      0.1740      0.047      3.728      0.000       0.083       0.265
# first_purchase_days_ago      -0.0024      0.012     -0.200      0.842      -0.026       0.021
# recent_purchase_days_ago     -0.0011      0.015     -0.072      0.943      -0.030       0.028
# sales_channel_2               0.1588      4.766      0.033      0.973      -9.183       9.501
# most_common_age_bin_20-29     0.9375      5.050      0.186      0.853      -8.961      10.836
# most_common_age_bin_30-39     0.1820      5.416      0.034      0.973     -10.434      10.798
# most_common_age_bin_40-49    -1.2841      6.711     -0.191      0.848     -14.437      11.868
# most_common_age_bin_50-59    -3.5664      5.752     -0.620      0.535     -14.840       7.707
# most_common_age_bin_60+            0   3.22e-05          0      1.000   -6.32e-05    6.32e-05
# ar.L1                        -0.0668      0.064     -1.036      0.300      -0.193       0.060
# ma.L1                        -0.8981      0.033    -27.361      0.000      -0.962      -0.834
# ar.S.L7                       0.0673      0.072      0.929      0.353      -0.075       0.209
# ma.S.L7                      -0.9505      0.112     -8.516      0.000      -1.169      -0.732
# sigma2                       11.7224      1.213      9.668      0.000       9.346      14.099
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                28.29
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.05   Skew:                            -0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.56e+24. Standard errors may be unstable.
#
# === Fold 3 - Model Summary (Dropping std_price & club_member_ratio) ===
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                 transaction_count   No. Observations:                  355
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood                -880.514
# Date:                           Thu, 06 Feb 2025   AIC                           1797.028
# Time:                                   16:46:49   BIC                           1866.316
# Sample:                               02-12-2019   HQIC                          1824.616
#                                     - 02-01-2020
# Covariance Type:                             opg
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# avg_price                    91.2122     67.746      1.346      0.178     -41.568     223.993
# unique_customers              1.2225      0.021     59.400      0.000       1.182       1.263
# unique_articles_sold         -0.8073      0.374     -2.160      0.031      -1.540      -0.075
# median_age                    0.0717      0.071      1.014      0.311      -0.067       0.210
# fashion_news_subscribers      0.1919      0.030      6.413      0.000       0.133       0.250
# first_purchase_days_ago       0.0024      0.007      0.360      0.719      -0.011       0.016
# recent_purchase_days_ago     -0.0054      0.008     -0.677      0.499      -0.021       0.010
# sales_channel_2               0.0030      4.019      0.001      0.999      -7.875       7.881
# most_common_age_bin_20-29     0.1598      4.511      0.035      0.972      -8.682       9.002
# most_common_age_bin_30-39    -0.0369      4.638     -0.008      0.994      -9.126       9.053
# most_common_age_bin_40-49    -0.1633      5.671     -0.029      0.977     -11.278      10.951
# most_common_age_bin_50-59    -1.5992      4.952     -0.323      0.747     -11.304       8.106
# most_common_age_bin_60+            0    7.2e-06          0      1.000   -1.41e-05    1.41e-05
# ar.L1                        -0.1053      0.043     -2.452      0.014      -0.190      -0.021
# ma.L1                        -0.8610      0.025    -34.917      0.000      -0.909      -0.813
# ar.S.L7                      -0.0103      0.048     -0.216      0.829      -0.104       0.083
# ma.S.L7                      -0.8820      0.044    -19.977      0.000      -0.969      -0.795
# sigma2                        8.4194      0.442     19.027      0.000       7.552       9.287
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):               115.60
# Prob(Q):                              0.78   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.12   Skew:                            -0.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.7e+23. Standard errors may be unstable.
#
# === Fold 4 - Model Summary (Dropping std_price & club_member_ratio) ===
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                 transaction_count   No. Observations:                  472
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood               -1255.945
# Date:                           Thu, 06 Feb 2025   AIC                           2547.889
# Time:                                   16:46:54   BIC                           2622.407
# Sample:                               02-12-2019   HQIC                          2577.222
#                                     - 05-28-2020
# Covariance Type:                             opg
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# avg_price                    59.3431     52.928      1.121      0.262     -44.394     163.081
# unique_customers              1.1614      0.019     60.457      0.000       1.124       1.199
# unique_articles_sold          0.4656      0.252      1.844      0.065      -0.029       0.960
# median_age                    0.0164      0.058      0.281      0.778      -0.098       0.130
# fashion_news_subscribers      0.2649      0.031      8.514      0.000       0.204       0.326
# first_purchase_days_ago      -0.0001      0.007     -0.019      0.985      -0.014       0.014
# recent_purchase_days_ago     -0.0021      0.009     -0.236      0.813      -0.019       0.015
# sales_channel_2               0.2016      3.893      0.052      0.959      -7.429       7.832
# most_common_age_bin_20-29     0.1142      6.797      0.017      0.987     -13.207      13.435
# most_common_age_bin_30-39     1.4997      6.871      0.218      0.827     -11.967      14.966
# most_common_age_bin_40-49     2.3217      7.845      0.296      0.767     -13.054      17.698
# most_common_age_bin_50-59    -1.0006      6.993     -0.143      0.886     -14.706      12.705
# most_common_age_bin_60+            0   3.13e-05          0      1.000   -6.13e-05    6.13e-05
# ar.L1                        -0.0522      0.045     -1.163      0.245      -0.140       0.036
# ma.L1                        -0.9160      0.021    -43.781      0.000      -0.957      -0.875
# ar.S.L7                      -0.0597      0.040     -1.497      0.134      -0.138       0.018
# ma.S.L7                      -0.9548      0.027    -35.619      0.000      -1.007      -0.902
# sigma2                       12.3753      0.693     17.851      0.000      11.017      13.734
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                33.00
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.04   Skew:                            -0.01
# Prob(H) (two-sided):                  0.81   Kurtosis:                         4.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.81e+22. Standard errors may be unstable.
#
# ===== Done! =====
# Fold metrics saved to: output/baseline_sarimax_one_item_dropped_cols/Bikini_top_Blue_Stripe_drop_cols_fold_metrics.csv
# Average metrics:
#           MAE        RMSE       MAPE          R2
# 0  77.736224  173.726066  39.862117 -597.972454
# Plots saved to: output/baseline_sarimax_one_item_dropped_cols/Bikini_top_Blue_Stripe_drop_cols_cv.png

# %%
import pandas as pd

# Define the full date range
full_period_start = pd.to_datetime("2018-09-20")
full_period_end = pd.to_datetime("2020-09-22")

# Calculate total days in that period (inclusive)
total_days_in_range = (full_period_end - full_period_start).days + 1

for pg in outlier_list:
    # Filter to just rows for this product group
    df_pg = data[data['product_group'] == pg].copy()
    
    # Ensure 'date' is a datetime
    df_pg['date'] = pd.to_datetime(df_pg['date'])
    
    # Further restrict to the full date range in question
    df_pg = df_pg[(df_pg['date'] >= full_period_start) & (df_pg['date'] <= full_period_end)]
    
    # How many unique days are present in the dataset for this product group?
    unique_days_recorded = df_pg['date'].nunique()
    
    # Days with no data are effectively "missing"
    missing_days = total_days_in_range - unique_days_recorded
    
    coverage_pct = (unique_days_recorded / total_days_in_range) * 100
    
    print(f"Product Group: {pg}")
    print(f"  Total days in [2018-09-20 .. 2020-09-22]:  {total_days_in_range}")
    print(f"  Days recorded in dataset:                 {unique_days_recorded}")
    print(f"  Missing days (no rows recorded):          {missing_days}")
    print(f"  Coverage:                                  {coverage_pct:.2f}%\n")
# Out:
# Product Group: Bikini top Beige All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 452
#   Missing days (no rows recorded):          282
#   Coverage:                                  61.58%
#
# Product Group: Bikini top Light Blue All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 573
#   Missing days (no rows recorded):          161
#   Coverage:                                  78.07%
#
# Product Group: Bikini top Light Blue Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 445
#   Missing days (no rows recorded):          289
#   Coverage:                                  60.63%
#
# Product Group: Blazer Black Stripe
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 590
#   Missing days (no rows recorded):          144
#   Coverage:                                  80.38%
#
# Product Group: Blouse Dark Turquoise Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 616
#   Missing days (no rows recorded):          118
#   Coverage:                                  83.92%
#
# Product Group: Dress Orange All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 522
#   Missing days (no rows recorded):          212
#   Coverage:                                  71.12%
#
# Product Group: Hat/beanie Black Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 690
#   Missing days (no rows recorded):          44
#   Coverage:                                  94.01%
#
# Product Group: Night gown Black Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 691
#   Missing days (no rows recorded):          43
#   Coverage:                                  94.14%
#
# Product Group: Pyjama bottom Black Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 731
#   Missing days (no rows recorded):          3
#   Coverage:                                  99.59%
#
# Product Group: Pyjama set Light Grey Front print
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 438
#   Missing days (no rows recorded):          296
#   Coverage:                                  59.67%
#
# Product Group: Scarf Black Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 675
#   Missing days (no rows recorded):          59
#   Coverage:                                  91.96%
#
# Product Group: Shirt Dark Green Check
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 690
#   Missing days (no rows recorded):          44
#   Coverage:                                  94.01%
#
# Product Group: Shorts Light Orange Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 587
#   Missing days (no rows recorded):          147
#   Coverage:                                  79.97%
#
# Product Group: Skirt Dark Green All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 584
#   Missing days (no rows recorded):          150
#   Coverage:                                  79.56%
#
# Product Group: Socks Black Glittering/Metallic
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 587
#   Missing days (no rows recorded):          147
#   Coverage:                                  79.97%
#
# Product Group: Sweater Black All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 708
#   Missing days (no rows recorded):          26
#   Coverage:                                  96.46%
#
# Product Group: Sweater Black Glittering/Metallic
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 591
#   Missing days (no rows recorded):          143
#   Coverage:                                  80.52%
#
# Product Group: Sweater Dark Blue Front print
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 685
#   Missing days (no rows recorded):          49
#   Coverage:                                  93.32%
#
# Product Group: Sweater Dark Green Melange
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 694
#   Missing days (no rows recorded):          40
#   Coverage:                                  94.55%
#
# Product Group: Sweater Dark Grey Melange
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 716
#   Missing days (no rows recorded):          18
#   Coverage:                                  97.55%
#
# Product Group: Sweater Dark Red Melange
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 697
#   Missing days (no rows recorded):          37
#   Coverage:                                  94.96%
#
# Product Group: Sweater Dark Turquoise Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 614
#   Missing days (no rows recorded):          120
#   Coverage:                                  83.65%
#
# Product Group: Sweater Off White Application/3D
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 474
#   Missing days (no rows recorded):          260
#   Coverage:                                  64.58%
#
# Product Group: Sweater Yellow Other structure
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 567
#   Missing days (no rows recorded):          167
#   Coverage:                                  77.25%
#
# Product Group: Swimsuit Light Beige All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 409
#   Missing days (no rows recorded):          325
#   Coverage:                                  55.72%
#
# Product Group: Swimwear bottom Light Yellow Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 548
#   Missing days (no rows recorded):          186
#   Coverage:                                  74.66%
#
# Product Group: Swimwear bottom White Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 713
#   Missing days (no rows recorded):          21
#   Coverage:                                  97.14%
#
# Product Group: Swimwear bottom Yellow All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 434
#   Missing days (no rows recorded):          300
#   Coverage:                                  59.13%
#
# Product Group: T-shirt Light Pink Melange
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 701
#   Missing days (no rows recorded):          33
#   Coverage:                                  95.50%
#
# Product Group: T-shirt Red Stripe
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 673
#   Missing days (no rows recorded):          61
#   Coverage:                                  91.69%
#
# Product Group: Trousers Light Beige Check
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 574
#   Missing days (no rows recorded):          160
#   Coverage:                                  78.20%
#
# Product Group: Trousers Red Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 692
#   Missing days (no rows recorded):          42
#   Coverage:                                  94.28%
#
# Product Group: Underwear Tights Black All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 629
#   Missing days (no rows recorded):          105
#   Coverage:                                  85.69%
#
# Product Group: Underwear body Black Lace
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 548
#   Missing days (no rows recorded):          186
#   Coverage:                                  74.66%
#
# Product Group: Underwear bottom Black Contrast
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 676
#   Missing days (no rows recorded):          58
#   Coverage:                                  92.10%
#
# Product Group: Vest top Dark Yellow Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 564
#   Missing days (no rows recorded):          170
#   Coverage:                                  76.84%
#
# Product Group: Dress Light Orange All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 485
#   Missing days (no rows recorded):          249
#   Coverage:                                  66.08%
#
# Product Group: Underwear bottom Red Lace
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 438
#   Missing days (no rows recorded):          296
#   Coverage:                                  59.67%
#
# Product Group: Blouse Light Green All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 504
#   Missing days (no rows recorded):          230
#   Coverage:                                  68.66%
#
# Product Group: Trousers Red Check
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 418
#   Missing days (no rows recorded):          316
#   Coverage:                                  56.95%
#
# Product Group: Bikini top Yellow All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 386
#   Missing days (no rows recorded):          348
#   Coverage:                                  52.59%
#
# Product Group: Swimwear bottom Red All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 361
#   Missing days (no rows recorded):          373
#   Coverage:                                  49.18%
#
# Product Group: Sarong Black Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 507
#   Missing days (no rows recorded):          227
#   Coverage:                                  69.07%
#
# Product Group: Bikini top Blue Stripe
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 506
#   Missing days (no rows recorded):          228
#   Coverage:                                  68.94%
#
# Product Group: Swimwear bottom Blue Stripe
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 490
#   Missing days (no rows recorded):          244
#   Coverage:                                  66.76%
#
# Product Group: Swimwear bottom Dark Green Other structure
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 515
#   Missing days (no rows recorded):          219
#   Coverage:                                  70.16%
#
# Product Group: Bikini top Dark Green Other structure
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 484
#   Missing days (no rows recorded):          250
#   Coverage:                                  65.94%
#
# Product Group: Bikini top White Other structure
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 500
#   Missing days (no rows recorded):          234
#   Coverage:                                  68.12%
#
# Product Group: Bikini top Off White All over pattern
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 503
#   Missing days (no rows recorded):          231
#   Coverage:                                  68.53%
#
# Product Group: Shorts Dark Orange Solid
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 490
#   Missing days (no rows recorded):          244
#   Coverage:                                  66.76%
#
# Product Group: Bikini top Light Blue Other structure
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 282
#   Missing days (no rows recorded):          452
#   Coverage:                                  38.42%
#
# Product Group: Swimwear bottom Light Blue Other structure
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 313
#   Missing days (no rows recorded):          421
#   Coverage:                                  42.64%
#
# Product Group: Swimwear bottom Other Pink Other structure
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 273
#   Missing days (no rows recorded):          461
#   Coverage:                                  37.19%
#
# Product Group: Bikini top Light Purple Other structure
#   Total days in [2018-09-20 .. 2020-09-22]:  734
#   Days recorded in dataset:                 220
#   Missing days (no rows recorded):          514
#   Coverage:                                  29.97%

# %%
import os
import glob
import pandas as pd

# Folder containing subdirectories for each item
transfer_dir = "final_version/output/1_day/transfer"

# Use glob to find all avg_metrics.csv files under transfer/*
csv_files = glob.glob(os.path.join(transfer_dir, "*", "avg_metrics.csv"))

# List to store DataFrames of metrics
metrics_list = []

for csv_file in csv_files:
    try:
        df = pd.read_csv(csv_file)
        metrics_list.append(df)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")

if metrics_list:
    # Concatenate all metrics into one DataFrame
    all_metrics_df = pd.concat(metrics_list, ignore_index=True)
    # Compute the mean of each column and round to 4 decimals
    avg_metrics = all_metrics_df.mean().round(4)
    
    print("Average metrics over all items:")
    print(avg_metrics)
    
    # Optionally, save the results to a CSV file
    output_file = os.path.join(transfer_dir, "avg_metrics_all.csv")
    avg_metrics.to_csv(output_file, header=True)
else:
    print("No avg_metrics.csv files found in the transfer directory.")
# Out:
# Average metrics over all items:
# Fold     2.5000
# MAE      0.0525
# RMSE     0.0837
# MAPE    31.6770
# R2       0.0766
# dtype: float64
